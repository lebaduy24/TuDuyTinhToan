# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input())
print (2*n)
# Out:
# 4

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a, b = map(float,input().split())
r = a/2
s_tron = 3.14*(r**2)
s_hcn = a*b
print (f'Diện tích còn để trồng cây xung quanh là {s_hcn - s_tron:.2f}')
# Out:
# Diện tích còn để trồng cây xung quanh là 8.86

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
a = str(input())
h = a.upper()
t = a.lower()
if (a==h):
    print (t)
else:
    print (h)
# Out:
# HELLO

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet

# %%
c = input()
if ('a' <= c <= 'z' ) or ('A'  <= c <= 'Z'):
    print (f"{c} là kí tự alphabet")
else:
    print (f"{c} không phải là kí tự alphabet")
# Out:
# ấ không phải là kí tự alphabet

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input("Nhập một chữ cái hoa: ")
if c == 'A':
    print ('z')
else:
    chu_thuong = c.lower()
    ket_qua = chr(ord(chu_thuong) - 1)
    print (ket_qua)
# Out:
# g

# %% [markdown]
# Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
import math
a, b, c = sorted(map(float,input().split()))
"""
hàm sorted là phân loại số từ bé đến lớn 
ví dụ nhập 10 3 4 thì sẽ cho ra 3 4 10
"""
if a + b > c:
    p = (a+b+c)/2
    dien_tich = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print (f"Diện tích của tam giác là: {dien_tich:.1f}")
else:
    print ("Khong phai 3 canh cua tam giac")
# Out:
# Khong phai 3 canh cua tam giac

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
a = input("Nhập chuỗi: ")
if a == a.upper():
    print ("Vui lòng nhập các kí tự thường!")
elif len(a) >= 20:
    print ("Chữ thứ 5 là",a[4] ,"và chữ thứ 9 là",a[8])
else:
    print ('Chuỗi kí tự phải trên hoặc bằng 20')
# Out:
# Chữ thứ 5 là c và chữ thứ 9 là l

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
#
# Từ 0 – 50kWh: 1.984 đồng/kWh
#
# Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh

# %%
chu_ho = str(input('Nhập tên chủ hộ:'))
print ("Ho va ten:",chu_ho)
cu = int(input("Chỉ số cũ là:"))
moi = int(input("Chỉ số mới là:"))
so_tien = moi - cu
if so_tien < 0:
    print ("Chỉ số không hợp lệ")
elif so_tien <= 50:
    print ('Tiền điện tháng này là:', so_tien * 1984 + (so_tien * 1984 * 0.08))
elif 50 < so_tien <= 100:
    print ('Tiền điện tháng này là:', so_tien * 2050 + (so_tien * 2050 * 0.08))
elif 100 < so_tien<= 200:
    print ('Tiền điện tháng này là:', so_tien * 2380 + (so_tien * 2380 * 0.08))
elif 200 < so_tien <= 300:
    print ('Tiền điện tháng này là:', so_tien * 2998 + (so_tien * 2998 * 0.08))
elif 300 < so_tien <= 400:
    print ('Tiền điện tháng này là:', so_tien * 3350 + (so_tien * 3350 * 0.08))
elif 400 < so_tien:
    print ('Tiền điện tháng này là:', so_tien * 3460 + (so_tien * 3460 * 0.08))
else:
    print ("Chỉ số điện không hợp lệ")
# Out:
# Ho va ten: le ba duy
# Tiền điện tháng này là: 2802600.0

# %% [markdown]
# Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ.

# %%
so = int(input())
if so % 2 == 0:
    print (so, 'là số chẵn')
else:
    print (so, 'là số lẻ')
# Out:
# 3 là số lẻ

# %% [markdown]
# Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra
# số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
if n % 10 == 5:
    print (True)
else:
    print (False)
# Out:
# True

# %% [markdown]
# Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên,
# kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra
# “False”.

# %%
n = int(input())
if n % 3 == 0 and n % 5 == 0:
    print (True)
else:
    print (False)
# Out:
# True

# %% [markdown]
# Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một
# người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
nam_sinh = int(input())
tuoi = 2026 - nam_sinh
if tuoi > 17:
    print ('Đủ tuổi')
else:
    print ('Không đủ tuổi')
# Out:
# Không đủ tuổi

# %% [markdown]
# So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo
# nếu hai số bằng nhau.

# %%
a,b = map(float,input().split())
if a == b:
    print ("Hai số bằng nhau")
elif a > b:
    print (f'số {a} lớn hơn số {b}')
else:
    print (f'số {b} lớn hơn số {a}')
# Out:
# Hai số bằng nhau

# %% [markdown]
# Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm
# tra xem ký tự đó là chữ cái hay số.

# %%
k = input()
if k.isalpha():
    print ('Đó là chữ cái')
elif k.isdigit():
    print ("Đó là số")
else:
    print ("Ký tự không xác định")
# Out:
# Đó là chữ cái

# %% [markdown]
# Bài tập 5: Tính điểm học lực
# Nhập điểm (0-10), phân loại học lực theo quy tắc:
# >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
diem = float(input())
if diem >= 0 and diem < 5 :
    print ("Yếu")
elif diem >= 5 and diem < 6.5:
    print ('Trung Bình')
elif diem >= 6.5 and diem < 8:
    print ("Khá")
elif diem >= 8 and diem <= 10:
    print ("Giỏi")
else:
    print ("Điểm không hợp lệ")
# Out:
# Trung Bình

# %% [markdown]
# Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4
# nhưng không chia hết cho 100)

# %%
nam = int(input())
if (nam % 400 == 0 or nam % 4 == 0) and (nam % 100 != 0):
    print ("Năm nhuận")
else:
    print ("Không phải năm nhuận")
# Out:
# Năm nhuận

# %% [markdown]
# Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số
# tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
so = int(input())
match so:
    case 0:
        print ("Không")
    case 1:
        print ("Một")
    case 2:
        print ("Hai")
    case 3:
        print ("Ba")
    case 4:
        print ("Bốn")
    case 5: 
        print ("Năm")
    case 6:
        print ("Sáu")
    case 7:
        print ("Bảy")
    case 8:
        print ("Tám")
    case 9:
        print ("Chín")
    case _:
        print ("Số không hợp lệ")
# Out:
# Số không hợp lệ

# %% [markdown]
# Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >=
# 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
diem = float(input())
if 0 <= diem < 4 :
    print ("Học lại")
elif 4 <= diem <= 10:
    print ("Qua môn")
else:
    print ("Điểm không hợp lệ")
# Out:
# Học lại

# %% [markdown]
# Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm
# hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
nam_sinh = int(input())
tuoi = 2025 - nam_sinh
if tuoi >= 18:
    print ("Đủ tuổi")
else:
    print ("Không đủ tuổi")
# Out:
# Không đủ tuổi
